# %%
import numpy as np, pandas as pd, unicodedata, pickle, re

# %%
txtfilename = "quotes.txt"
txtfile = open(txtfilename)

# %%
r = re.compile("(.*?)(http(s?)://.+)?(\s\w{3}\s\d{2},\s\d{4})$")
def clean(s):
    m = r.match(s)
    return m.group(1)

# %%
clean('"qsdfmlqsmdflkj qsmdlkfj mqsdlfkj " - Qqsdf qsdf ht qsdf Dec 15, 2015')
# Out:
# '"qsdfmlqsmdflkj qsmdlkfj mqsdlfkj " - Qqsdf qsdf ht qsdf'

# %%
def char2idx(c):
    return ord(c)
def toascii(s):
    return unicodedata.normalize("NFKD", s).encode("ascii", "ignore")
def tostring(lc):
    return "".join(map(chr, lc))

# %%
with open("quotes.clean.txt","w") as outf:
    for line in txtfile:
        try: 
            outf.write(clean(line)+"\n")
        except AttributeError:
            print line

# %%
datamat = []
for line in txtfile:
    idxs = map(char2idx, toascii(line.decode("utf8")))
    datamat.append(idxs)

# %%
df = pd.DataFrame(datamat)

# %%
data = df.fillna(0).values

# %%
savefile = "quotes.np.pkl"
pickle.dump(data, open(savefile, "w"))

# %%
sdata = pickle.load(open(savefile))

# %%
l = 100
li = 0
for q in sdata:
    print tostring(map(int, q))
    li += 1
    if li > l:
        break
# Out:
# "He who must travel happily must travel light." - Antoine de Saint-Exup?ry Dec 18, 2015
#
# "Your time is limited, so don't waste it living someone else's life." - Steve Jobs Dec 18, 2015
#
# "Do you want to know who you are? Don't ask. Act! Action will delineate and define you." - Thomas Jefferson Dec 18, 2015
#
# "To fear love is to fear life, and those who fear life are already 3-parts dead." - Bertrand Russell Dec 18, 2015
#
# "Every victory is only the price of admission to a more difficult problem - Henry Kissinger Dec 18, 2015
#
# "Every worthy act is difficult. Ascent is always difficult. Descent is easy and often slippery." - Mahatma Gandhi Dec 18, 2015
#
# "Everyone sees what you appear to be, few experience what you really are." - Niccol? Machiavelli Dec 18, 2015
#
# "We must begin thinking like a river if we are to leave a legacy of beauty and life for future generations." - David Brower Dec 18, 2015
#
# "If there is no struggle, there is no progress." - Frederick Douglass Dec 18, 2015
#
# "Memories mean more to me than dresses." - Anne Frank Dec 17, 2015
#
# "It is the trouble that never comes that causes the loss of sleep." - Charles Austin Bates Dec 17, 2015
#
# "True happiness comes from the joy of deeds well done, the zest of creating things new." - Antoine de Saint-Exupery Dec 17, 2015
#
# "Imagine your ideal future. Visualize yourself as if your life were perfect in every respect." - Brian Tracy Dec 17, 2015
#
# "Some cause happiness wherever they go; others whenever they go." - Oscar Wilde Dec 17, 2015
#
# "Each success only buys an admission ticket to a more difficult problem." - Henry Kissinger Dec 17, 2015
#
# "Real growth comes through intense, difficult, and challenging situations."  Kamal Ravikant Dec 17, 2015
#
# "Vision is the art of seeing the invisible." - Jonathan Swift Dec 17, 2015
#
# "There are just some kind of menwhore so busy worrying about the next world theyve never learned to live in this one." - Harper Lee Dec 17, 2015
#
# "Laziness may appear attractive, but work gives satisfaction." - Anne Frank Dec 17, 2015
#
# "Commit to living your truth."  @kamalravikant Dec 17, 2015
#
# "No one has ever become poor by giving." - Anne Frank Dec 16, 2015
#
# "Age is foolish and forgetful when it underestimates youth." - J. K. Rowling Dec 16, 2015
#
# "Love and you shall be loved." - Ralph Waldo Emerson Dec 16, 2015
#
# "I never panic when I get lost. I just change where it is I want to go." - Rita Rudner Dec 16, 2015
#
# "The good news is that once the spotlight shines from within yourself, there is no going back."  @kamalravikant Dec 16, 2015
#
# "The only way to survive with grace is to forgive." - Lesley Garner Dec 16, 2015
#
# "In true dialogue, both sides are willing to change." - Thich Nhat Hanh Dec 16, 2015
#
# "Do what you feel in your heart to be right  for youll be criticized anyway." - Eleanor Roosevelt Dec 16, 2015
#
# "Any fool can fight a winning battle, but it needs character to fight a losing one, and that should inspire us." - W..B. Yeats Dec 16, 2015
#
# "One can choose to go back toward safety or forward toward growth." - Abraham Maslow Dec 16, 2015
#
# "Trust men and they will be true to you; treat them greatly and they will show themselves great." - Ralph Waldo Emerson Dec 16, 2015
#
# "Turn your wounds into wisdom." - Oprah Winfrey Dec 15, 2015
#
# "A stumbling block to the pessimist is a stepping-stone to the optimist." - Eleanor Roosevelt Dec 15, 2015
#
# "To produce we must be able to make endless mistakes." - Lesley Garner Dec 15, 2015
#
# "Few things help an individual more than to place responsibility upon him, and to let him know that you trust him." - Booker T. Washington Dec 15, 2015
#
# "Walking is man's best medicine." - Hippocrates Dec 15, 2015
#
# "Don't learn to do, but learn in doing." - Samuel Butler Dec 15, 2015
#
# "To conquer fear is the beginning of wisdom." - Bertrand Russell Dec 15, 2015
#
# "Experience is merely the name men gave to their mistakes." - Oscar Wilde Dec 15, 2015
#
# "If you deliberately set out to be less than you are capable, you'll be unhappy for the rest of your life." - Abraham Maslow Dec 15, 2015
#
# "You are never too old to chase your dreams." - Diana Nyad Dec 15, 2015
#
# "If the only tool you have is a hammer, all your problems begin to look like nails." - Abraham Maslow Dec 15, 2015
#
# "Sharing tales of those we've lost is how we keep from really losing them." - Mitch Albom Dec 14, 2015
#
# "Look at how a single candle can both defy and define the darkness." - Anne Frank Dec 14, 2015
#
# "Our vision is more obstructed by what we think we know than by our lack of knowledge." - Kristen Stendahl Dec 14, 2015
#
# "Never judge a book by its movie." - J.W. Eagan Dec 14, 2015
#
# "He who is not everyday conquering some fear has not learned the secret of life." - Ralph Waldo Emerson Dec 14, 2015
#
# "Gratitude is always a good place to start from in the middle of turmoil."  Leslie Garner" Dec 14, 2015
#
# "People generally see what they look for, and hear what they listen for."- Harper Lee Dec 14, 2015
#
# "Belief consists in accepting the affirmations of the soul; unbelief, in denying them." - Ralph Waldo Emerson Dec 14, 2015
#
# "Be content with what you have; rejoice in the way things are. When you realize there is nothing lacking."- Lao Tzu Dec 14, 2015
#
# "As we are liberated from our fear, our presence automatically liberates others."" - Marianne Williamson Dec 14, 2015
#
# "Change your opinions, keep to your principles; change your leaves, keep intact your roots." - Victor Hugo Dec 14, 2015
#
# "If you begin to practice forgiveness , it has the power of the drip of water that wears away the stone."  Lesley Garner Dec 13, 2015
#
# "To handle yourself, use your head; to handle others, use your heart." - Eleanor Roosevelt Dec 13, 2015
#
# "Because you are alive, everything is possible." - Th?ch Nhat Hanh Dec 13, 2015
#
# "Don't be afraid to be unique or speak your mind, because that's what makes you different from everyone else." - Dave Thomas Dec 13, 2015
#
# "If something else matters to you, then do that."  @kamalravikant Dec 13, 2015
#
# "If something else matters to you, then do that." @kamalravikant https://t.co/nD6UObao13 Dec 13, 2015
#
# "Every morning we are born again. What we do today is what matters most." - Buddha Dec 13, 2015
#
# "Education is not the filling of a pail, but the lighting of a fire." - W.B. Yeats Dec 13, 2015
#
# "Prefer to be defeated in the presence of the wise than to excel among fools." - Dogen Dec 13, 2015
#
# "Nurture your mind with great thoughts, for you will never go any higher than you think." - Benjamin Disraeli Dec 13, 2015
#
# "The greatest good you can do for another is not just to share your riches but to reveal to him his own." - Benjamin Disraeli Dec 13, 2015
#
# "What is my life if I am no longer useful to others." - Goethe Dec 13, 2015
#
# "There is nothing impossible to him who will try." - Alexander the Great Dec 09, 2015
#
# "In the midst of movement and chaos, keep stillness inside of you." - Deepak Chopra Dec 09, 2015
#
# Learn from yesterday, live for today, hope for tomorrow. - Unknown Source Dec 05, 2015
#
# Big fleas have little fleas, Upon their backs to bite 'em, And little fleas have lesser fleas, and so, ad infinitum. - Augustus De Morgan Dec 05, 2015
#
# Sometimes Ive believed as many as six impossible things before breakfast.  Lewis Carroll Dec 03, 2015
#
# "Nothing is more intolerable than to have to admit to yourself your own errors." - Ludwig van Beethoven Dec 02, 2015
#
# "Happiness depends upon ourselves." - Aristotle Nov 24, 2015
#
# "When one must, one can." - Charlotte Whitton Nov 21, 2015
#
# "Never give up on what you really want to do. The person with big dreams is more powerful than one with all the facts." - Albert Einstein Nov 21, 2015
#
# "Great things are not done by impulse, but by a series of small things brought together." - Vincent van Gogh Nov 21, 2015
#
# "Victory is sweetest when you've known defeat." - Malcolm Forbes Nov 21, 2015
#
# "I failed my way to success." - Thomas Edison Nov 21, 2015
#
# "No one succeeds without effort. Those who succeed owe their success to perseverance." - Ramana Maharshi Nov 21, 2015
#
# "It is hard to fail, but it is worse never to have tried to succeed." - Theodore Roosevelt Nov 21, 2015
#
# "A single conversation across the table with a wise person is worth a month's study of books." - Chinese Proverb Nov 21, 2015
#
# "The average teacher explains complexity; the gifted teacher reveals simplicity." - Robert Brault Nov 21, 2015
#
# "Braille is knowledge, and knowledge is power." - Louis Braille Nov 20, 2015
#
# Nothing is built on stone; all is built on sand, but we must build as if the sand were stone. - Jorge Luis Borges Nov 20, 2015
#
# Things are never so bad they can't be made worse. - Humphrey Bogart Nov 20, 2015
#
# It is easier to forgive an enemy than to forgive a friend. - William Blake Nov 20, 2015
#
# "If the doors of perception were cleansed everything would appear to man as it is, infinite. - William Blake Nov 20, 2015
#
# "Think in the morning. Act in the noon. Eat in the evening. Sleep in the night." - William Blake Nov 20, 2015
#
# "He who asks is a fool for five minutes, but he who does not ask remains a fool forever." - Chinese Proverb Nov 20, 2015
#
# "I am the wisest man alive, for I know one thing, and that is that I know nothing." - Plato Nov 20, 2015
#
# "Courage is knowing what not to fear. - Playto Nov 20, 2015
#
# "Kind words can be short and easy to speak, but their echoes are truly endless." - Mother Teresa Nov 20, 2015
#
# "Differences are not intended to separate, to alienate. We are different precisely in order to realize our need of one another." - D Tutu Nov 20, 2015
#
# "Don't raise your voice, improve your argument." - Desmond Tutu Nov 19, 2015
#
# "I have the simplest tastes. I am always satisfied with the best." - Oscar Wilde Nov 19, 2015
#
# "Do your little bit of good where you are; it's those little bits of good put together that overwhelm the world." - Desmond Tutu Nov 19, 2015
#
# "Be not afraid of greatness. Some are born great, some achieve greatness, and others have greatness thrust upon them." - William Shakespeare Nov 19, 2015
#
# "The fool doth think he is wise, but the wise man knows himself to be a fool." - William Shakespeare Nov 19, 2015
#
# "Do not look for happiness outside yourself. The awakened seek happiness inside." - Peter Deunov Nov 19, 2015
#
# "The true value of a human being can be found in the degree to which he has attained liberation from the self." - Albert Einstein Nov 19, 2015
#
# "There is creative reading as well as creative writing." - Ralph Waldo Emerson Nov 19, 2015
#
# "Education is the kindling of a flame, not the filling of a vessel." - Socrates Nov 19, 2015
